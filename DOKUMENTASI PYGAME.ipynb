# %% [markdown]
# # DOKUMENTASI PYGAME
# __DIBUAT OLEH :__
#     1. SHOFI MUBAROK (180441100028)
#     2. MOCH. SULTHON ALIF DES SAFRI (180441100152)
#
# __A. PENGERTIAN PYGAME__
#
# Pygame adalah seperangkat modul python yang dirancang untuk membuat suatu permainan. Didalam pygame tersebut  terdapat fungsi- fungsi tersendiri seperti halnya untuk bagian multimedia, seperti karakter game, sound, dan lain sebagainya.Pygame sendiri menggunkan library SDL yang memungkinkan para pengguna dapat menggunkan berbagai macam fitur dan fungsi yang disediakan oleh pygame.
#
# Pygame sendiri memiliki beberapa keunggulan yakni mudah di mengerti bagi pemula, berlisensi gratis, dan memiliki beberapa komunitas yang dapat membantu dalam belajar.
#
# __B. INSTALASI PYGAME__
#
# Sebelum membuat game, hal yang harus dilakukan pertama kali adalah menginstall modul pygame tersebut terlebih dahulu. Berikut adalah langkah-langkah dalam menginstall modul pygame:
# 1.	Buka CMD, kemudian ketikkan “pip”
# 2.	Setelah muncul menu dari pip itu sendiri kemudian ketik “pip install pygame”
# 3.	Kemudian akan otomatis mendownload file instalasi modul pygame. Jika sudah muncul tulisan “Successfully installed pygame-1.9.6” , maka pygame sudah terinstall.
#
# __C. PENJELASAN CLASS__
#
# Semua class yang digunakan dalam pembuatan game mewarisi class sprite milik pygame
# ![](./gambar1/utama.PNG)
#
# __1.Class Player__
# ![](./gambar1/p.PNG)
#
# Pada class player terdapat 3 method yang method inisialisasi, method update, method shoot. Ketiga method tersebut memiliki atribut dan fungsi masing masing. Yaitu :
#
# A.	Inisialisasi
# - Sebuah sprite harus mewarisi sprite dari library pygame
# - Pygame.image.load berfungsi untuk membaca asset gambar untuk digunakan dalam game
# - Atribut vx dan vy merupakan posisi awal player
# - Atribut shield adalah banyak nyawa yang dimiliki oleh player
# - Atribut shoot_delay berfungsi untuk membuat interval banyaknya peluru yang keluar melalui player
#
# B.	Update
# - Method ini digunakan untuk mendeteksi tombol keyboard panah (atas,bawah) yang berfungsi untuk menggerakkan player
# - Tombol keyboard yang ditekan di deteksi dengan menggunakan key.get_pressed()
#
# C.	Shoot
# - Method ini mewarisi sifat dari kelas dibawahnya yakni Bullet
# - Shoot_sound.play() adalah mengambil variabel diluar kelas agar saat menembakkan peluru dapat membaca assets berupa suara yang akan digunakan kedalam game
#
#
# __2.Class Bullet__
# ![](./gambar1/b.PNG)
#
# Pada class player terdapat 2 method yang method inisialisasi, method update. Kedua method tersebut memiliki atribut dan fungsi masing masing. Yaitu :
#
# A.	Inisialisasi
# - Sebuah sprite harus mewarisi sprite dari library pygame
# - Pygame.image.load berfungsi untuk membaca asset gambar untuk digunakan dalam game
#
# B.  Update
# - Atribut rect.x berfungsi untuk kecepetan peluru saat diluncurkan
#
# __3.Class Pow__
# ![](./gambar1/po.PNG)
#
# Pada class player terdapat 2 method yang method inisialisasi, method update. Kedua method tersebut memiliki atribut dan fungsi masing masing. Yaitu :
#
# A.  Inisialisasi
# - Atribut type digunakan untuk memilih secara random variabel shield (nyawa tambahan)
# - Atribut image untuk mengakses gambar agar ditampilkan dalam game
# - Atribut rect x dan y berfungsi agar gambar shield (nyawa tambahan) yang dikeluarkan dapat muncul secara acak.
# - Atribut speedy berfungsi untuk kecepatan shield (nyawa tambahan) saat melaju
#
# B.  Update
# - Method ini berfungsi untuk memunculkan shield (nyawa tambahan) agar bisa muncul didalam game
#
# __4. Class Enemy__
# ![](./gambar1/e.PNG)
#
# Pada class player terdapat 2 method yang method inisialisasi, method update. Kedua method tersebut memiliki atribut dan fungsi masing masing. Yaitu :
#
# A.	Inisialisasi
# - Sebuah sprite harus mewarisi sprite dari library pygame
# - Pygame.image.load berfungsi untuk membaca asset gambar untuk digunakan dalam game
# - Atribut rect x dan y berfungsi agar gambar shield yang dikeluarkan dapat muncul secara acak.
# - Atribut speedy berfungsi untuk kecepatan shield saat melaju
#
# B.	Update
# - Method ini berfungsi untuk memunculkan musuh agar bisa muncul didalam game secara random
#
# __D. KONSEP OOP YANG DIGUNAKAN__
#
# Konsep yang OOP yang digunakan dalam game ini adalah Inheritance (Super), Contohnya:
# ![](./gambar1/super1.PNG)
# ![](./gambar1/super2.PNG)
# ![](./gambar1/super3.PNG)
#
# __E. VARIABEL GAME DAN PENEJELASANNYA__
# ![](./gambar1/awal.PNG)
# ![](./gambar1/tengah1.PNG)
# ![](./gambar1/done.PNG)
#
# __F. LOOPING GAME__
# ![](./gambar1/perulangan1.PNG)
# ![](./gambar1/perulangan2.PNG)
#
# __G. TAMPILAN GAME__
#
# - Tampilan Awaal saat masuk game
# ![](./gambar1/game1%20.PNG)
#
#
# - Tampilan saat dimainkan
# ![](./gambar1/game2.PNG)
#
#
# - Tampilan Game Over Screen
# ![](./gambar1/game3.PNG)
